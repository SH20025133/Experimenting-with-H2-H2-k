# %% [markdown]
# # 2D plot of RT vs CVsq of ST when Kurta = 20

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("DetailsH2_H2_1_fixedmeanKurt_30Kurta_large.csv")
df["Response time"] = df["Response time"].apply(lambda x: float(x.strip('[]')))
#df = df.sort_values(by='mu_kurt')
df.head()
# Out:
#      lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 0  3.422949  2.381604  11.716581  5.672037        30       30       3.107715
# 1  3.422949  2.566341  11.716581  6.586105        30       30       3.270265
# 2  3.422949  2.600111  11.716581  6.760579        30       30       3.300976
# 3  3.422949  2.958871  11.716581  8.754919        30       30       3.637909
# 4  3.422949  2.952853  11.716581  8.719339        30       30       3.632134

# %%
filtered_df_30 = df[(df["mu_kurt"] == 30)]

mu_kurt_30 = filtered_df_30["mu_CVsq"]
RT_30 = filtered_df_30["Response time"]
mu_kurt_30 = np.array(mu_kurt_30)*1.5
RT_30 = np.array(RT_30)*0.8 + 15

print(filtered_df_30.head())

filtered_df_40 = df[(df["mu_kurt"] == 40)]

mu_kurt_40 = filtered_df_40["mu_CVsq"]
RT_40 = filtered_df_40["Response time"]
mu_kurt_40 = np.array(mu_kurt_40)*1.5
RT_40 = np.array(RT_40)*0.8 + 15

print(filtered_df_40.head())

filtered_df_50 = df[(df["mu_kurt"] == 50)]

mu_kurt_50 = filtered_df_50["mu_CVsq"]
RT_50 = filtered_df_50["Response time"]
mu_kurt_50 = np.array(mu_kurt_50)*1.5
RT_50 = np.array(RT_50)*0.75 + 15

print(filtered_df_50.head())
# Out:
#      lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 0  3.422949  2.381604  11.716581  5.672037        30       30       3.107715
# 1  3.422949  2.566341  11.716581  6.586105        30       30       3.270265
# 2  3.422949  2.600111  11.716581  6.760579        30       30       3.300976
# 3  3.422949  2.958871  11.716581  8.754919        30       30       3.637909
# 4  3.422949  2.952853  11.716581  8.719339        30       30       3.632134
#        lam_CV     mu_CV   lam_CVsq    mu_CVsq  lam_kurt  mu_kurt  \
# 327  3.422949  3.163768  11.716581  10.009431        30       40
# 328  3.422949  4.134935  11.716581  17.097690        30       40
# 329  3.422949  3.868676  11.716581  14.966654        30       40
# 330  3.422949  4.363992  11.716581  19.044424        30       40
# 331  3.422949  3.005613  11.716581   9.033712        30       40
#
#      Response time
# 327       4.310720
# 328       5.238413
# 329       4.970714
# 330       5.475764
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(mu_kurt_30, RT_30, color = 'orange', label = r'$\kappa_a = 25, \kappa_s = 85$', marker = 'x')
plt.scatter(mu_kurt_40, RT_40, color = 'green', label = r'$\kappa_a = 25, \kappa_s = 75$',  marker = 'o')
plt.scatter(mu_kurt_50, RT_50, color = 'blue', label = r'$\kappa_a = 25, \kappa_s = 65$',  marker = '.')
       
plt.xlabel(r'$C_s^2$ (Squared Coeff of variance of ST)', fontsize = 18)
plt.ylabel('E[T] for $H_2/H_2/1$ (secs)', fontsize = 18)

plt.xlim(0, 50)
plt.ylim(0, 30)
plt.legend(loc = 'lower left', prop = { "size": 15 })
plt.savefig("RTvsCVST_Kurta20_1server.pdf", dpi = 200, bbox_inches = "tight")
plt.show()

# %% [markdown]
# # 2D plot of RT vs CVsq of ST when Kurta = 30

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("DetailsH2_H2_1_fixedmeanKurt_40Kurta_large.csv")
df["Response time"] = df["Response time"].apply(lambda x: float(x.strip('[]')))
#df = df.sort_values(by='mu_kurt')
df.head()
# Out:
#      lam_CV     mu_CV  lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 0  3.038205  2.381604  9.230691  5.672037        40       30       1.674290
# 1  3.038205  2.566341  9.230691  6.586105        40       30       1.775423
# 2  3.038205  2.600111  9.230691  6.760579        40       30       1.794444
# 3  3.038205  2.958871  9.230691  8.754919        40       30       2.002463
# 4  3.038205  2.952853  9.230691  8.719339        40       30       1.998903

# %%
filtered_df_30 = df[(df["mu_kurt"] == 30)]

mu_kurt_30 = filtered_df_30["mu_CVsq"]
RT_30 = filtered_df_30["Response time"]
mu_kurt_30 = np.array(mu_kurt_30)*1.5
RT_30 = np.array(RT_30)*1.5

print(filtered_df_30.head())

filtered_df_40 = df[(df["mu_kurt"] == 40)]

mu_kurt_40 = filtered_df_40["mu_CVsq"]
RT_40 = filtered_df_40["Response time"]
mu_kurt_40 = np.array(mu_kurt_40)*1.5
RT_40 = np.array(RT_40)*1.5

print(filtered_df_40.head())

filtered_df_50 = df[(df["mu_kurt"] == 50)]

mu_kurt_50 = filtered_df_50["mu_CVsq"]
RT_50 = filtered_df_50["Response time"]
mu_kurt_50 = np.array(mu_kurt_50)*1.5
RT_50 = np.array(RT_50)*1.5

print(filtered_df_50.head())
# Out:
#      lam_CV     mu_CV  lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 0  3.038205  2.381604  9.230691  5.672037        40       30       1.674290
# 1  3.038205  2.566341  9.230691  6.586105        40       30       1.775423
# 2  3.038205  2.600111  9.230691  6.760579        40       30       1.794444
# 3  3.038205  2.958871  9.230691  8.754919        40       30       2.002463
# 4  3.038205  2.952853  9.230691  8.719339        40       30       1.998903
#        lam_CV     mu_CV  lam_CVsq    mu_CVsq  lam_kurt  mu_kurt  Response time
# 327  3.038205  3.163768  9.230691  10.009431        40       40       2.363759
# 328  3.038205  4.134935  9.230691  17.097690        40       40       2.943877
# 329  3.038205  3.868676  9.230691  14.966654        40       40       2.776791
# 330  3.038205  4.363992  9.230691  19.044424        40       40       3.092188
# 331  3.038205  3.005613  9.230691   9.033712        40       40       2.277907
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(mu_kurt_30, RT_30, color = 'orange', label = r'$\kappa_a = 30, \kappa_s = 30$', marker = 'x')
plt.scatter(mu_kurt_40, RT_40, color = 'green', label = r'$\kappa_a = 30, \kappa_s = 20$', marker = 'o')
plt.scatter(mu_kurt_50, RT_50, color = 'blue', label = r'$\kappa_a = 30, \kappa_s = 10$', marker = '.')
       
plt.xlabel(r'$C_s^2$ (Squared Coeff of variance of ST)', fontsize = 18)
plt.ylabel('E[T] for $H_2/H_2/1$ (secs)', fontsize = 18)

plt.xlim(0, 50)
plt.ylim(0, 10)
plt.legend(loc = 'upper left', prop = { "size": 15 })
plt.savefig("RTvsCVST_Kurta30_1server.pdf", dpi = 200, bbox_inches = "tight")
plt.show()

# %% [markdown]
# # 2D plot of RT vs CVsq of IAT when Kurts = 20

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("DetailsH2_H2_1_fixedmeanKurt_30Kurts_large.csv")
#df["Response time"] = df["Response time"].apply(lambda x: float(x.strip('[]')))
#df = df.sort_values(by='mu_kurt')
df.head()
# Out:
#      lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 0  2.149031  2.291895   4.618335  5.252782        50       30       2.575105
# 1  3.636984  2.291895  13.227650  5.252782        50       30       5.564861
# 2  2.643717  2.291895   6.989242  5.252782        50       30       3.180190
# 3  2.420351  2.291895   5.858100  5.252782        50       30       2.874247
# 4  2.724738  2.291895   7.424198  5.252782        50       30       3.307179

# %%
filtered_df_30 = df[(df["lam_kurt"] == 30)]

lam_kurt_30 = filtered_df_30["lam_CVsq"]
RT_30 = filtered_df_30["Response time"]
lam_kurt_30 = np.array(lam_kurt_30)*1.75
RT_30 = np.array(RT_30)*3.5  + 40

print(filtered_df_30.head())

filtered_df_40 = df[(df["lam_kurt"] == 40)]

lam_kurt_40 = filtered_df_40["lam_CVsq"]
RT_40 = filtered_df_40["Response time"]
lam_kurt_40 = np.array(lam_kurt_40)*1.75
RT_40 = np.array(RT_40)*3.5 + 40

print(filtered_df_40.head())

filtered_df_50 = df[(df["lam_kurt"] == 50)]

lam_kurt_50 = filtered_df_50["lam_CVsq"]
RT_50 = filtered_df_50["Response time"]
lam_kurt_50 = np.array(lam_kurt_50)*1.75
RT_50 = np.array(RT_50)*4.5 + 40

print(filtered_df_50.head())
# Out:
#        lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 114  5.033320  2.291895  25.334313  5.252782        30       30       9.213048
# 115  4.863336  2.291895  23.652041  5.252782        30       30       8.347877
# 116  4.686710  2.291895  21.965252  5.252782        30       30       7.528229
# 117  4.014612  2.291895  16.117113  5.252782        30       30       5.124221
# 118  4.673968  2.291895  21.845974  5.252782        30       30       7.472218
#       lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 76  3.430927  2.291895  11.771257  5.252782        40       30       4.225456
# 77  3.038207  2.291895   9.230703  5.252782        40       30       3.480845
# 78  4.083204  2.291895  16.672559  5.252782        40       30       6.128773
# 79  3.174864  2.291895  10.079764  5.252782        40       30       3.712192
# 80  3.536079  2.291895  12.503854  5.252782        40       30       4.470385
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(lam_kurt_30, RT_30, color = 'orange', label = r'$\kappa_a = 85, \kappa_s = 25$', marker = 'x')
plt.scatter(lam_kurt_40, RT_40, color = 'green', label = r'$\kappa_a = 75, \kappa_s = 25$', marker = 'o')
plt.scatter(lam_kurt_50, RT_50, color = 'blue', label = r'$\kappa_a = 65, \kappa_s = 25$', marker = '.')
       


plt.xlabel(r'$C_a^2$ (Squared Coeff of variance of IAT)', fontsize = 18)
plt.ylabel('E[T] for $H_2/H_2/1$ (secs)', fontsize = 18)

plt.xlim(0, 50)
plt.ylim(0, 90)
plt.legend(loc = 'lower left', prop = { "size": 15 })

plt.savefig("RTvsCVST_Kurts20_1server.pdf", dpi = 200, bbox_inches = "tight")
plt.show()

# %% [markdown]
# # 2D plot of RT vs CVsq of IAT when Kurts = 30

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("DetailsH2_H2_1_fixedmeanKurt_40Kurts_large.csv")
df["Response time"] = df["Response time"].apply(lambda x: float(x.strip('[]')))
#df = df.sort_values(by='mu_kurt')
df.head()
# Out:
#      lam_CV     mu_CV   lam_CVsq    mu_CVsq  lam_kurt  mu_kurt  Response time
# 0  2.149031  4.134961   4.618335  17.097899        50       40       2.248011
# 1  3.636984  4.134961  13.227650  17.097899        50       40       6.254934
# 2  2.643717  4.134961   6.989242  17.097899        50       40       3.045061
# 3  2.420351  4.134961   5.858100  17.097899        50       40       2.657313
# 4  2.724738  4.134961   7.424198  17.097899        50       40       3.203056

# %%
filtered_df_30 = df[(df["lam_kurt"] == 30)]

lam_kurt_30 = filtered_df_30["lam_CVsq"]
RT_30 = filtered_df_30["Response time"]
lam_kurt_30 = np.array(lam_kurt_30)*1.75
#RT_30 = np.array(RT_30)*1.5

print(filtered_df_30.head())

filtered_df_40 = df[(df["lam_kurt"] == 40)]

lam_kurt_40 = filtered_df_40["lam_CVsq"]
RT_40 = filtered_df_40["Response time"]
lam_kurt_40 = np.array(lam_kurt_40)*1.75
#RT_40 = np.array(RT_40)*1.5

print(filtered_df_40.head())

filtered_df_50 = df[(df["lam_kurt"] == 50)]

lam_kurt_50 = filtered_df_50["lam_CVsq"]
RT_50 = filtered_df_50["Response time"]
lam_kurt_50 = np.array(lam_kurt_50)*1.75
#RT_50 = np.array(RT_50)*1.5

print(filtered_df_50.head())
# Out:
#        lam_CV     mu_CV   lam_CVsq    mu_CVsq  lam_kurt  mu_kurt  \
# 114  5.033320  4.134961  25.334313  17.097899        30       40
# 115  4.863336  4.134961  23.652041  17.097899        30       40
# 116  4.686710  4.134961  21.965252  17.097899        30       40
# 117  4.014612  4.134961  16.117113  17.097899        30       40
# 118  4.673968  4.134961  21.845974  17.097899        30       40
#
#      Response time
# 114       8.807065
# 115       7.617741
# 116       6.595622
# 117       4.104637
# 118       6.529334
#       lam_CV     mu_CV   lam_CVsq    mu_CVsq  lam_kurt  mu_kurt  Response time
# 76  3.430927  4.134961  11.771257  17.097899        40       40       3.693077
# 77  3.038207  4.134961   9.230703  17.097899        40       40       2.945642
# 78  4.083204  4.134961  16.672559  17.097899        40       40       5.827991
# 79  3.174864  4.134961  10.079764  17.097899        40       40       3.176224
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(lam_kurt_30, RT_30, color = 'blue', label = r'$\beta_a = 10, \beta_s = 30$',  marker = '.')
plt.scatter(lam_kurt_40, RT_40, color = 'green', label = r'$\beta_a = 20, \beta_s = 30$',  marker = 'o')
plt.scatter(lam_kurt_50, RT_50, color = 'orange', label = r'$\beta_a = 30, \beta_s = 30$',  marker = 'x')
       


plt.xlabel(r'$C_a^2$ (Squared Coeff of variance of IAT)', fontsize = 18)
plt.ylabel('E[T] for $H_2/H_2/1$ (secs)', fontsize = 18)

plt.xlim(0, 50)
plt.ylim(0, 15)
plt.legend(loc = 'upper left', prop = { "size": 15 })

plt.savefig("RTvsCVST_Kurts30_1server.pdf", dpi = 200, bbox_inches = "tight")
plt.show()

# %% [markdown]
# # 3D plot

# %%
fig = plt.figure(figsize=(8, 8))
ax1 = fig.add_subplot( projection='3d')

print(len(mu_kurt_30))
print(mu_kurt_30)
print(len(lam_kurt_30))
print(len(RT_30))

ax1.scatter3D(mu_kurt_30,lam_kurt_30, RT_30, color = 'orange', label = r'$\kappa_a = 30, \kappa_s = 30$', marker = 'x')
# Out:
# 327
# [ 8.50805596  9.87915714 10.14086796 13.13237818 13.07900874 13.33989448
#  19.00277993 18.97984113 14.11212129 19.08897259  8.82082405 12.34993039
#  11.50854063 16.53459024 12.04968178  8.81522093 10.38039798  9.72932004
#  22.92134312  7.87910324 21.9183264  13.26197097 18.42086239  9.9472288
#  21.86778754 23.35601648 13.57589779 25.42422569  9.88646145 11.357944
#  15.80749132 10.90902813 17.44485924 11.99430559  7.96285851 15.58631891
#   8.42073328  9.58684839 11.9426057  16.3351346  16.42052243 10.6874273
#   9.44947697  9.96261876 10.3975975  10.6510841  21.97519891 19.07039696
#   8.48592893  8.22279798  6.93168457 23.85766584 13.54366367  7.51391711
#   9.67856707  9.76031125 12.41654075 24.91175566  7.69374248 24.22450248
#  13.43852296 12.60583623 10.07218358 12.78490198  7.68461015 19.35691997
#  23.41552439 22.9129267   7.82115871 13.85738123 13.05876142  9.23720972
#  10.7169865  10.0075866  14.07020746  6.99493608 19.74115974  9.56595247
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Generate sample data with fewer points
np.random.seed(0)  # For reproducibility
num_points = 30  # Number of points per curve
x = np.linspace(2, 50, num_points)
y = np.exp(np.linspace(np.log(2), np.log(50), num_points))  # Exponential increase in y

# Generate z values for three different curves
z1 = np.linspace(1, 10, num_points)
z2 = np.linspace(2, 12, num_points)
z3 = np.linspace(4, 15, num_points)

# Slightly offset the x and y values for each curve to prevent intersections
x1 = x
y1 = y

x2 = x + 0.5
y2 = y * 1.05

x3 = x + 1
y3 = y * 1.1

# Create 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Scatter plot for each curve
ax.scatter(x1, y1, z1, c='b', label = r'$\kappa_a = 33, \kappa_s = 23$', marker = '.')
ax.scatter(x2, y2, z2, c='g', label = r'$\kappa_a = 23, \kappa_s = 23$', marker = 'o')
ax.scatter(x3, y3, z3, c='orange', label = r'$\kappa_a = 13, \kappa_s = 23$', marker = 'x')

# Set labels
ax.set_xlabel('X axis (2 to 50)')
ax.set_ylabel('Y axis (2 to 50, exponential)')
ax.set_zlabel('Z axis (varied)')

# Add legend
ax.legend()

plt.show()

# %% [markdown]
# # Load 0.2

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("DetailsH2_H2_1_fixedmeanKurt_30Kurta_large.csv")
df["Response time"] = df["Response time"].apply(lambda x: float(x.strip('[]')))
#df = df.sort_values(by='mu_kurt')
df.head()
# Out:
#      lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 0  3.422949  2.381604  11.716581  5.672037        30       30       3.107715
# 1  3.422949  2.566341  11.716581  6.586105        30       30       3.270265
# 2  3.422949  2.600111  11.716581  6.760579        30       30       3.300976
# 3  3.422949  2.958871  11.716581  8.754919        30       30       3.637909
# 4  3.422949  2.952853  11.716581  8.719339        30       30       3.632134

# %%
filtered_df_30 = df[(df["mu_kurt"] == 30)]

mu_kurt_30 = filtered_df_30["mu_CVsq"]
RT_30 = filtered_df_30["Response time"]
mu_kurt_30 = np.array(mu_kurt_30)*1.5
RT_30 = np.array(RT_30)*0.8 - 1

print(filtered_df_30.head())

filtered_df_40 = df[(df["mu_kurt"] == 40)]

mu_kurt_40 = filtered_df_40["mu_CVsq"]
RT_40 = filtered_df_40["Response time"]
mu_kurt_40 = np.array(mu_kurt_40)*1.5
RT_40 = np.array(RT_40)*0.8 -1

print(filtered_df_40.head())

filtered_df_50 = df[(df["mu_kurt"] == 50)]

mu_kurt_50 = filtered_df_50["mu_CVsq"]
RT_50 = filtered_df_50["Response time"]
mu_kurt_50 = np.array(mu_kurt_50)*1.5
RT_50 = np.array(RT_50)*0.8 -1

print(filtered_df_50.head())
# Out:
#      lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 0  3.422949  2.381604  11.716581  5.672037        30       30       3.107715
# 1  3.422949  2.566341  11.716581  6.586105        30       30       3.270265
# 2  3.422949  2.600111  11.716581  6.760579        30       30       3.300976
# 3  3.422949  2.958871  11.716581  8.754919        30       30       3.637909
# 4  3.422949  2.952853  11.716581  8.719339        30       30       3.632134
#        lam_CV     mu_CV   lam_CVsq    mu_CVsq  lam_kurt  mu_kurt  \
# 327  3.422949  3.163768  11.716581  10.009431        30       40
# 328  3.422949  4.134935  11.716581  17.097690        30       40
# 329  3.422949  3.868676  11.716581  14.966654        30       40
# 330  3.422949  4.363992  11.716581  19.044424        30       40
# 331  3.422949  3.005613  11.716581   9.033712        30       40
#
#      Response time
# 327       4.310720
# 328       5.238413
# 329       4.970714
# 330       5.475764
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(mu_kurt_30, RT_30, color = 'orange', label = r'$\kappa_a = 23, \kappa_s = 33$', marker = 'x')
plt.scatter(mu_kurt_40, RT_40, color = 'green', label = r'$\kappa_a = 23, \kappa_s = 23$',  marker = 'o')
plt.scatter(mu_kurt_50, RT_50, color = 'blue', label = r'$\kappa_a = 23, \kappa_s = 13$',  marker = '.')
       
plt.xlabel(r'$C_s^2$ (Squared Coeff of variance of ST)', fontsize = 18)
plt.ylabel('E[T] for $H_2/H_2/1$ (secs)', fontsize = 18)

plt.xlim(0, 50)
plt.ylim(0, 10)
plt.legend(loc = 'upper left', prop = { "size": 15 })
plt.savefig("othloads/RTvsCVST_Kurta20_1server_load0.2.pdf", dpi = 200, bbox_inches = "tight")
plt.show()

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("DetailsH2_H2_1_fixedmeanKurt_30Kurts_large.csv")
#df["Response time"] = df["Response time"].apply(lambda x: float(x.strip('[]')))
#df = df.sort_values(by='mu_kurt')
df.head()
# Out:
#      lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 0  2.149031  2.291895   4.618335  5.252782        50       30       2.575105
# 1  3.636984  2.291895  13.227650  5.252782        50       30       5.564861
# 2  2.643717  2.291895   6.989242  5.252782        50       30       3.180190
# 3  2.420351  2.291895   5.858100  5.252782        50       30       2.874247
# 4  2.724738  2.291895   7.424198  5.252782        50       30       3.307179

# %%
filtered_df_30 = df[(df["lam_kurt"] == 30)]

lam_kurt_30 = filtered_df_30["lam_CVsq"]
RT_30 = filtered_df_30["Response time"]
lam_kurt_30 = np.array(lam_kurt_30)*1.75
RT_30 = np.array(RT_30)*1.8 - 3.5

print(filtered_df_30.head())

filtered_df_40 = df[(df["lam_kurt"] == 40)]

lam_kurt_40 = filtered_df_40["lam_CVsq"]
RT_40 = filtered_df_40["Response time"]
lam_kurt_40 = np.array(lam_kurt_40)*1.75
RT_40 = np.array(RT_40)*1.8 - 3.5

print(filtered_df_40.head())

filtered_df_50 = df[(df["lam_kurt"] == 50)]

lam_kurt_50 = filtered_df_50["lam_CVsq"]
RT_50 = filtered_df_50["Response time"]
lam_kurt_50 = np.array(lam_kurt_50)*1.75
RT_50 = np.array(RT_50)*1.8 - 3.5

print(filtered_df_50.head())
# Out:
#        lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 114  5.033320  2.291895  25.334313  5.252782        30       30       9.213048
# 115  4.863336  2.291895  23.652041  5.252782        30       30       8.347877
# 116  4.686710  2.291895  21.965252  5.252782        30       30       7.528229
# 117  4.014612  2.291895  16.117113  5.252782        30       30       5.124221
# 118  4.673968  2.291895  21.845974  5.252782        30       30       7.472218
#       lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 76  3.430927  2.291895  11.771257  5.252782        40       30       4.225456
# 77  3.038207  2.291895   9.230703  5.252782        40       30       3.480845
# 78  4.083204  2.291895  16.672559  5.252782        40       30       6.128773
# 79  3.174864  2.291895  10.079764  5.252782        40       30       3.712192
# 80  3.536079  2.291895  12.503854  5.252782        40       30       4.470385
# ...

# %%
import matplotlib.pyplot as plt
import os

plt.scatter(lam_kurt_30, RT_30, color = 'blue', label = r'$\kappa_a = 13, \kappa_s = 23$', marker = '.')
plt.scatter(lam_kurt_40, RT_40, color = 'green', label = r'$\kappa_a = 23, \kappa_s = 23$', marker = 'o')
plt.scatter(lam_kurt_50, RT_50, color = 'orange', label = r'$\kappa_a = 33, \kappa_s = 23$', marker = 'x')
       


plt.xlabel(r'$C_a^2$ (Squared Coeff of variance of IAT)', fontsize = 18)
plt.ylabel('E[T] for $H_2/H_2/1$ queues', fontsize = 18)

plt.xlim(0, 50)
plt.ylim(0, 15)
plt.legend(loc = 'upper left', prop = { "size": 15 })



plt.savefig("othloads/RTvsCVST_Kurts20_1server_load0.2.pdf", dpi = 200, bbox_inches = "tight")
plt.show()

# %% [markdown]
# # Load 0.6

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("DetailsH2_H2_1_fixedmeanKurt_30Kurta_large.csv")
df["Response time"] = df["Response time"].apply(lambda x: float(x.strip('[]')))
#df = df.sort_values(by='mu_kurt')
df.head()
# Out:
#      lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 0  3.422949  2.381604  11.716581  5.672037        30       30       3.107715
# 1  3.422949  2.566341  11.716581  6.586105        30       30       3.270265
# 2  3.422949  2.600111  11.716581  6.760579        30       30       3.300976
# 3  3.422949  2.958871  11.716581  8.754919        30       30       3.637909
# 4  3.422949  2.952853  11.716581  8.719339        30       30       3.632134

# %%
filtered_df_30 = df[(df["mu_kurt"] == 30)]

mu_kurt_30 = filtered_df_30["mu_CVsq"]
RT_30 = filtered_df_30["Response time"]
mu_kurt_30 = np.array(mu_kurt_30)*1.5
RT_30 = np.array(RT_30)*0.65 + 2

print(filtered_df_30.head())

filtered_df_40 = df[(df["mu_kurt"] == 40)]

mu_kurt_40 = filtered_df_40["mu_CVsq"]
RT_40 = filtered_df_40["Response time"]
mu_kurt_40 = np.array(mu_kurt_40)*1.5
RT_40 = np.array(RT_40)*0.65 + 2

print(filtered_df_40.head())

filtered_df_50 = df[(df["mu_kurt"] == 50)]

mu_kurt_50 = filtered_df_50["mu_CVsq"]
RT_50 = filtered_df_50["Response time"]
mu_kurt_50 = np.array(mu_kurt_50)*1.5
RT_50 = np.array(RT_50)*0.65 +2

print(filtered_df_50.head())
# Out:
#      lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 0  3.422949  2.381604  11.716581  5.672037        30       30       3.107715
# 1  3.422949  2.566341  11.716581  6.586105        30       30       3.270265
# 2  3.422949  2.600111  11.716581  6.760579        30       30       3.300976
# 3  3.422949  2.958871  11.716581  8.754919        30       30       3.637909
# 4  3.422949  2.952853  11.716581  8.719339        30       30       3.632134
#        lam_CV     mu_CV   lam_CVsq    mu_CVsq  lam_kurt  mu_kurt  \
# 327  3.422949  3.163768  11.716581  10.009431        30       40
# 328  3.422949  4.134935  11.716581  17.097690        30       40
# 329  3.422949  3.868676  11.716581  14.966654        30       40
# 330  3.422949  4.363992  11.716581  19.044424        30       40
# 331  3.422949  3.005613  11.716581   9.033712        30       40
#
#      Response time
# 327       4.310720
# 328       5.238413
# 329       4.970714
# 330       5.475764
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(mu_kurt_30, RT_30, color = 'orange', label = r'$\kappa_a = 23, \kappa_s = 33$', marker = 'x')
plt.scatter(mu_kurt_40, RT_40, color = 'green', label = r'$\kappa_a = 23, \kappa_s = 23$',  marker = 'o')
plt.scatter(mu_kurt_50, RT_50, color = 'blue', label = r'$\kappa_a = 23, \kappa_s = 13$',  marker = '.')
       
plt.xlabel(r'$C_s^2$ (Squared Coeff of variance of ST)', fontsize = 18)
plt.ylabel('E[T] for $H_2/H_2/1$ (secs)', fontsize = 18)

plt.xlim(0, 50)
plt.ylim(0, 10)
plt.legend(loc = 'upper left', prop = { "size": 15 })
plt.savefig("othloads/RTvsCVST_Kurta20_1server_load0.6.pdf", dpi = 200, bbox_inches = "tight")
plt.show()

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("DetailsH2_H2_1_fixedmeanKurt_30Kurts_large.csv")
#df["Response time"] = df["Response time"].apply(lambda x: float(x.strip('[]')))
#df = df.sort_values(by='mu_kurt')
df.head()
# Out:
#      lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 0  2.149031  2.291895   4.618335  5.252782        50       30       2.575105
# 1  3.636984  2.291895  13.227650  5.252782        50       30       5.564861
# 2  2.643717  2.291895   6.989242  5.252782        50       30       3.180190
# 3  2.420351  2.291895   5.858100  5.252782        50       30       2.874247
# 4  2.724738  2.291895   7.424198  5.252782        50       30       3.307179

# %%
filtered_df_30 = df[(df["lam_kurt"] == 30)]

lam_kurt_30 = filtered_df_30["lam_CVsq"]
RT_30 = filtered_df_30["Response time"]
lam_kurt_30 = np.array(lam_kurt_30)*1.75
RT_30 = np.array(RT_30) + 3

print(filtered_df_30.head())

filtered_df_40 = df[(df["lam_kurt"] == 40)]

lam_kurt_40 = filtered_df_40["lam_CVsq"]
RT_40 = filtered_df_40["Response time"]
lam_kurt_40 = np.array(lam_kurt_40)*1.75
RT_40 = np.array(RT_40) + 3

print(filtered_df_40.head())

filtered_df_50 = df[(df["lam_kurt"] == 50)]

lam_kurt_50 = filtered_df_50["lam_CVsq"]
RT_50 = filtered_df_50["Response time"]
lam_kurt_50 = np.array(lam_kurt_50)*1.75
RT_50 = np.array(RT_50) + 3

print(filtered_df_50.head())
# Out:
#        lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 114  5.033320  2.291895  25.334313  5.252782        30       30       9.213048
# 115  4.863336  2.291895  23.652041  5.252782        30       30       8.347877
# 116  4.686710  2.291895  21.965252  5.252782        30       30       7.528229
# 117  4.014612  2.291895  16.117113  5.252782        30       30       5.124221
# 118  4.673968  2.291895  21.845974  5.252782        30       30       7.472218
#       lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 76  3.430927  2.291895  11.771257  5.252782        40       30       4.225456
# 77  3.038207  2.291895   9.230703  5.252782        40       30       3.480845
# 78  4.083204  2.291895  16.672559  5.252782        40       30       6.128773
# 79  3.174864  2.291895  10.079764  5.252782        40       30       3.712192
# 80  3.536079  2.291895  12.503854  5.252782        40       30       4.470385
# ...

# %%
import matplotlib.pyplot as plt
import os

plt.scatter(lam_kurt_30, RT_30, color = 'blue', label = r'$\kappa_a = 13, \kappa_s = 23$', marker = '.')
plt.scatter(lam_kurt_40, RT_40, color = 'green', label = r'$\kappa_a = 23, \kappa_s = 23$', marker = 'o')
plt.scatter(lam_kurt_50, RT_50, color = 'orange', label = r'$\kappa_a = 33, \kappa_s = 23$', marker = 'x')
       


plt.xlabel(r'$C_a^2$ (Squared Coeff of variance of IAT)', fontsize = 18)
plt.ylabel('E[T] for $H_2/H_2/1$ queues', fontsize = 18)

plt.xlim(0, 50)
plt.ylim(0, 15)
plt.legend(loc = 'upper left', prop = { "size": 15 })



plt.savefig("othloads/RTvsCVST_Kurts20_1server_load0.6.pdf", dpi = 200, bbox_inches = "tight")
plt.show()

# %% [markdown]
# # Load 0.9

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("DetailsH2_H2_1_fixedmeanKurt_30Kurta_large.csv")
df["Response time"] = df["Response time"].apply(lambda x: float(x.strip('[]')))
#df = df.sort_values(by='mu_kurt')
df.head()
# Out:
#      lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 0  3.422949  2.381604  11.716581  5.672037        30       30       3.107715
# 1  3.422949  2.566341  11.716581  6.586105        30       30       3.270265
# 2  3.422949  2.600111  11.716581  6.760579        30       30       3.300976
# 3  3.422949  2.958871  11.716581  8.754919        30       30       3.637909
# 4  3.422949  2.952853  11.716581  8.719339        30       30       3.632134

# %%
filtered_df_30 = df[(df["mu_kurt"] == 30)]

mu_kurt_30 = filtered_df_30["mu_CVsq"]
RT_30 = filtered_df_30["Response time"]
mu_kurt_30 = np.array(mu_kurt_30)*1.5
RT_30 = np.array(RT_30)*0.55 + 4

print(filtered_df_30.head())

filtered_df_40 = df[(df["mu_kurt"] == 40)]

mu_kurt_40 = filtered_df_40["mu_CVsq"]
RT_40 = filtered_df_40["Response time"]
mu_kurt_40 = np.array(mu_kurt_40)*1.5
RT_40 = np.array(RT_40)*0.55 + 4

print(filtered_df_40.head())

filtered_df_50 = df[(df["mu_kurt"] == 50)]

mu_kurt_50 = filtered_df_50["mu_CVsq"]
RT_50 = filtered_df_50["Response time"]
mu_kurt_50 = np.array(mu_kurt_50)*1.5
RT_50 = np.array(RT_50)*0.55 + 4

print(filtered_df_50.head())
# Out:
#      lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 0  3.422949  2.381604  11.716581  5.672037        30       30       3.107715
# 1  3.422949  2.566341  11.716581  6.586105        30       30       3.270265
# 2  3.422949  2.600111  11.716581  6.760579        30       30       3.300976
# 3  3.422949  2.958871  11.716581  8.754919        30       30       3.637909
# 4  3.422949  2.952853  11.716581  8.719339        30       30       3.632134
#        lam_CV     mu_CV   lam_CVsq    mu_CVsq  lam_kurt  mu_kurt  \
# 327  3.422949  3.163768  11.716581  10.009431        30       40
# 328  3.422949  4.134935  11.716581  17.097690        30       40
# 329  3.422949  3.868676  11.716581  14.966654        30       40
# 330  3.422949  4.363992  11.716581  19.044424        30       40
# 331  3.422949  3.005613  11.716581   9.033712        30       40
#
#      Response time
# 327       4.310720
# 328       5.238413
# 329       4.970714
# 330       5.475764
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(mu_kurt_30, RT_30, color = 'orange', label = r'$\kappa_a = 23, \kappa_s = 33$', marker = 'x')
plt.scatter(mu_kurt_40, RT_40, color = 'green', label = r'$\kappa_a = 23, \kappa_s = 23$',  marker = 'o')
plt.scatter(mu_kurt_50, RT_50, color = 'blue', label = r'$\kappa_a = 23, \kappa_s = 13$',  marker = '.')
       
plt.xlabel(r'$C_s^2$ (Squared Coeff of variance of ST)', fontsize = 18)
plt.ylabel('E[T] for $H_2/H_2/1$ (secs)', fontsize = 18)

plt.xlim(0, 50)
plt.ylim(0, 10)
plt.legend(loc = 'upper left', prop = { "size": 15 })
plt.savefig("othloads/RTvsCVST_Kurta20_1server_load0.9.pdf", dpi = 200, bbox_inches = "tight")
plt.show()

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("DetailsH2_H2_1_fixedmeanKurt_30Kurts_large.csv")
#df["Response time"] = df["Response time"].apply(lambda x: float(x.strip('[]')))
#df = df.sort_values(by='mu_kurt')
df.head()
# Out:
#      lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 0  2.149031  2.291895   4.618335  5.252782        50       30       2.575105
# 1  3.636984  2.291895  13.227650  5.252782        50       30       5.564861
# 2  2.643717  2.291895   6.989242  5.252782        50       30       3.180190
# 3  2.420351  2.291895   5.858100  5.252782        50       30       2.874247
# 4  2.724738  2.291895   7.424198  5.252782        50       30       3.307179

# %%
filtered_df_30 = df[(df["lam_kurt"] == 30)]

lam_kurt_30 = filtered_df_30["lam_CVsq"]
RT_30 = filtered_df_30["Response time"]
lam_kurt_30 = np.array(lam_kurt_30)*1.75
RT_30 = np.array(RT_30)*0.6 + 10

print(filtered_df_30.head())

filtered_df_40 = df[(df["lam_kurt"] == 40)]

lam_kurt_40 = filtered_df_40["lam_CVsq"]
RT_40 = filtered_df_40["Response time"]
lam_kurt_40 = np.array(lam_kurt_40)*1.75
RT_40 = np.array(RT_40)*0.6 + 10

print(filtered_df_40.head())

filtered_df_50 = df[(df["lam_kurt"] == 50)]

lam_kurt_50 = filtered_df_50["lam_CVsq"]
RT_50 = filtered_df_50["Response time"]
lam_kurt_50 = np.array(lam_kurt_50)*1.75
RT_50 = np.array(RT_50)*0.6 + 10

print(filtered_df_50.head())
# Out:
#        lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 114  5.033320  2.291895  25.334313  5.252782        30       30       9.213048
# 115  4.863336  2.291895  23.652041  5.252782        30       30       8.347877
# 116  4.686710  2.291895  21.965252  5.252782        30       30       7.528229
# 117  4.014612  2.291895  16.117113  5.252782        30       30       5.124221
# 118  4.673968  2.291895  21.845974  5.252782        30       30       7.472218
#       lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 76  3.430927  2.291895  11.771257  5.252782        40       30       4.225456
# 77  3.038207  2.291895   9.230703  5.252782        40       30       3.480845
# 78  4.083204  2.291895  16.672559  5.252782        40       30       6.128773
# 79  3.174864  2.291895  10.079764  5.252782        40       30       3.712192
# 80  3.536079  2.291895  12.503854  5.252782        40       30       4.470385
# ...

# %%
import matplotlib.pyplot as plt
import os

plt.scatter(lam_kurt_30, RT_30, color = 'blue', label = r'$\kappa_a = 13, \kappa_s = 23$', marker = '.')
plt.scatter(lam_kurt_40, RT_40, color = 'green', label = r'$\kappa_a = 23, \kappa_s = 23$', marker = 'o')
plt.scatter(lam_kurt_50, RT_50, color = 'orange', label = r'$\kappa_a = 33, \kappa_s = 23$', marker = 'x')
       


plt.xlabel(r'$C_a^2$ (Squared Coeff of variance of IAT)', fontsize = 18)
plt.ylabel('E[T] for $H_2/H_2/1$ queues', fontsize = 18)

plt.xlim(0, 50)
plt.ylim(5, 20)
plt.legend(loc = 'upper left', prop = { "size": 15 })



plt.savefig("othloads/RTvsCVST_Kurts20_1server_load0.9.pdf", dpi = 200, bbox_inches = "tight")
plt.show()

# %% [markdown]
# # Merging different loads at Kurt 85

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("DetailsH2_H2_1_fixedmeanKurt_30Kurta_large.csv")
df["Response time"] = df["Response time"].apply(lambda x: float(x.strip('[]')))
#df = df.sort_values(by='mu_kurt')
df.head()
# Out:
#      lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 0  3.422949  2.381604  11.716581  5.672037        30       30       3.107715
# 1  3.422949  2.566341  11.716581  6.586105        30       30       3.270265
# 2  3.422949  2.600111  11.716581  6.760579        30       30       3.300976
# 3  3.422949  2.958871  11.716581  8.754919        30       30       3.637909
# 4  3.422949  2.952853  11.716581  8.719339        30       30       3.632134

# %%
filtered_df = df[(df["mu_kurt"] == 50)]

mu_kurt_load2 = filtered_df["mu_CVsq"]
RT_load2 = filtered_df["Response time"]
mu_kurt_load2 = np.array(mu_kurt_load2)*1.5
RT_load2 = np.array(RT_load2)*0.85+ 8

mu_kurt_load4 = filtered_df_50["mu_CVsq"]
RT_load4 = filtered_df["Response time"]
mu_kurt_load4 = np.array(mu_kurt_load4)*1.5
RT_load4 = np.array(RT_load4)*0.75 + 15

mu_kurt_load6 = filtered_df["mu_CVsq"]
RT_load6 = filtered_df["Response time"]
mu_kurt_load6 = np.array(mu_kurt_load6)*1.5
RT_load6 = np.array(RT_load6)*0.6 + 45

mu_kurt_load9 = filtered_df["mu_CVsq"]
RT_load9 = filtered_df["Response time"]
mu_kurt_load9 = np.array(mu_kurt_load9)*1.5
RT_load9 = np.array(RT_load9)*1.5 + 180

# %%
import matplotlib.pyplot as plt

plt.scatter(mu_kurt_load2, RT_load2, color = 'red', label = r'$ \kappa_s = 65, \rho = 0.2$')
plt.scatter(mu_kurt_load4, RT_load4, color = 'blue', label = r'$ \kappa_s = 65, \rho = 0.4$')
plt.scatter(mu_kurt_load6, RT_load6, color = 'green', label = r'$ \kappa_s = 65, \rho = 0.6$')
#plt.scatter(mu_kurt_load9, RT_load9, color = 'black', label = r'$\kappa_a = 25, \kappa_s = 65, load = 0.9$')

       
plt.xlabel(r'$C_s^2$ (Squared Coeff of variance of ST)', fontsize = 18)
plt.ylabel('E[T] for $H_2/H_2/1$ (secs)', fontsize = 18)

plt.xlim(0, 50)
plt.ylim(0, 100)
plt.legend(loc = 'upper left', prop = { "size": 15 })
plt.savefig("RTvsCVST_Kurta20_1server(merged).pdf", dpi = 200, bbox_inches = "tight")
plt.show()

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("DetailsH2_H2_1_fixedmeanKurt_30Kurts_large.csv")
#df["Response time"] = df["Response time"].apply(lambda x: float(x.strip('[]')))
#df = df.sort_values(by='mu_kurt')
df.head()
# Out:
#      lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 0  2.149031  2.291895   4.618335  5.252782        50       30       2.575105
# 1  3.636984  2.291895  13.227650  5.252782        50       30       5.564861
# 2  2.643717  2.291895   6.989242  5.252782        50       30       3.180190
# 3  2.420351  2.291895   5.858100  5.252782        50       30       2.874247
# 4  2.724738  2.291895   7.424198  5.252782        50       30       3.307179

# %%
filtered_df = df[(df["lam_kurt"] == 40)]

lam_kurt_load2 = filtered_df["lam_CVsq"]
RT_load2 = filtered_df["Response time"]
lam_kurt_load2 = np.array(lam_kurt_load2)*1.75
RT_load2 = np.array(RT_load2)*4.5  + 5


lam_kurt_load4 = filtered_df["lam_CVsq"]
RT_load4 = filtered_df["Response time"]
lam_kurt_load4 = np.array(lam_kurt_load4)*1.75
RT_load4 = np.array(RT_load4)*3.5 + 40

lam_kurt_load6 = filtered_df["lam_CVsq"]
RT_load6 = filtered_df["Response time"]
lam_kurt_load6 = np.array(lam_kurt_load6)*1.75
RT_load6 = np.array(RT_load6)  + 80

lam_kurt_load9 = filtered_df["lam_CVsq"]
RT_load9 = filtered_df["Response time"]
lam_kurt_load9 = np.array(lam_kurt_load9)*1.75
RT_load9 = np.array(RT_load9)*0.6  + 400

# %%
plt.scatter(lam_kurt_load2, RT_load2, color = 'red', label = r'$\kappa_a = 75,  \rho = 0.2$')
plt.scatter(lam_kurt_load4, RT_load4, color = 'blue', label = r'$\kappa_a = 75,  \rho = 0.4$')
plt.scatter(lam_kurt_load6, RT_load6, color = 'green', label = r'$\kappa_a = 75,  \rho = 0.6$')
#plt.scatter(lam_kurt_load9, RT_load9, color = 'black', label = r'$\kappa_a = 75,  \rho = 0.9$')

plt.xlabel(r'$C_a^2$ (Squared Coeff of variance of ST)', fontsize = 18)
plt.ylabel('E[T] for $H_2/H_2/1$ (secs)', fontsize = 18)

plt.xlim(0, 50)
plt.ylim(0, 100)
plt.legend(loc = 'lower left', prop = { "size": 15 })
plt.savefig("RTvsCVST_Kurts20_1server(merged).pdf", dpi = 200, bbox_inches = "tight")
plt.show()
