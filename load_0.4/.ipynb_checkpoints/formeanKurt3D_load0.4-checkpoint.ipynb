# %% [markdown]
# # 3D plots from records (IAT fixed, ST changing)

# %%
import numpy as np
import sympy as sp
import pandas as pd
import math
from scipy.interpolate import griddata
import matplotlib.pyplot as plt

# %%
#IAT fixed, ST changing
df = pd.read_csv('DetailsH2_H2_1_fixedmean_CVa.csv')
df = df.sort_values(by='mu_kurt')


filtered_df_121 = df[(df["coeffST_sq"] == 1.21) & (df["lam_kurt"] <= 300) & (df["mu_kurt"] <= 400)]

lam_kurt_121 = filtered_df_121["lam_kurt"]
mu_kurt_121 = filtered_df_121["mu_kurt"]
RT_121 = filtered_df_121["Response time"]

print(filtered_df_121.head())

filtered_df_4 = df[(df["coeffST_sq"] == 4) & (df["lam_kurt"] <= 300) & (df["mu_kurt"] <= 400)]

lam_kurt_4 = filtered_df_4["lam_kurt"]
mu_kurt_4 = filtered_df_4["mu_kurt"]
RT_4 = filtered_df_4["Response time"]
print(filtered_df_4.head())

filtered_df_25 = df[(df["coeffST_sq"] == 25) & (df["lam_kurt"] <= 300) & (df["mu_kurt"] <= 400)]

lam_kurt_25 = filtered_df_25["lam_kurt"]
mu_kurt_25 = filtered_df_25["mu_kurt"]
RT_25 = filtered_df_25["Response time"]
print(filtered_df_25.head())

filtered_df_64 = df[(df["coeffST_sq"] == 64) & (df["lam_kurt"] <= 300) & (df["mu_kurt"] <= 400)]

lam_kurt_64 = filtered_df_64["lam_kurt"]
mu_kurt_64 = filtered_df_64["mu_kurt"]
RT_64 = filtered_df_64["Response time"]
print(filtered_df_64.head())
# Out:
#       coeffIAT_sq  coeffST_sq    lam_kurt   mu_kurt  Response time
# 2803           16        1.21   74.574020  9.353002       9.959330
# 2840           16        1.21  125.901561  9.353038       5.467203
# 891            16        1.21   48.248066  9.353067      14.224769
# 1961           16        1.21  283.696402  9.353768       2.860649
# 823            16        1.21   48.421679  9.354146      14.190804
#       coeffIAT_sq  coeffST_sq    lam_kurt    mu_kurt  Response time
# 3320           16         4.0   59.279428  12.758081      13.484666
# 5496           16         4.0   49.193345  12.768532      14.999572
# 4768           16         4.0  188.152283  12.779315       6.013223
# 5485           16         4.0   68.136666  12.782233      12.349246
# 3074           16         4.0  183.497080  12.788548       6.106055
#       coeffIAT_sq  coeffST_sq    lam_kurt    mu_kurt  Response time
# 6037           16        25.0   69.893481  75.326850      20.693679
# 7742           16        25.0  116.887525  75.354494      18.693387
# 8241           16        25.0  218.979035  75.381951      16.473036
# 7607           16        25.0   88.153507  75.398008      19.778738
# 7271           16        25.0   98.357050  75.419914      19.352428
#        coeffIAT_sq  coeffST_sq    lam_kurt     mu_kurt  Response time
# 14809           16        64.0  134.168442  192.094057      32.918520
# 11809           16        64.0  134.168442  192.094057      32.918520
# 11489           16        64.0  126.949922  192.111047      33.047858
# 14489           16        64.0  126.949922  192.111047      33.047858
# 10235           16        64.0   74.219092  192.192138      34.260414

# %%
fig = plt.figure(figsize=(8, 8))
ax1 = fig.add_subplot( projection='3d')

ax1.scatter3D(lam_kurt_121, mu_kurt_121, RT_121, label = 'CVa = 4, CVs = 1.1')
ax1.scatter3D(lam_kurt_4, mu_kurt_4, RT_4, label = 'CVa = 4, CVs = 2')
ax1.scatter3D(lam_kurt_25, mu_kurt_25, RT_25, label = 'CVa = 4, CVs = 5')
ax1.scatter3D(lam_kurt_64, mu_kurt_64, RT_64, label = 'CVa = 4, CVs = 8')

ax1.set_xlim(0, 400)
ax1.set_ylim(50,400)
ax1.set_zlim(0,50)
ax1.view_init(elev=0, azim=15)


ax1.set_xlabel('Kurtosis of IAT curve')
ax1.set_ylabel('Kurtosis of ST curve')
ax1.set_zlabel('RT for H2/H2/1 as per Tarasov for different Ca, Cs')

for tick in ax1.get_xticklabels():
    tick.set_rotation(60)
    tick.set_horizontalalignment('right')


plt.legend()
plt.show()

# %% [markdown]
# # 3D plots from records (ST fixed, IAT changing)

# %%
#ST fixed, IAT changing
df = pd.read_csv('DetailsH2_H2_1_fixedmean_CVs.csv')
df = df.sort_values(by='lam_kurt')


filtered_df_121 = df[(df["coeffIAT_sq"] == 1.21) & (df["lam_kurt"] <= 300) & (df["mu_kurt"] <= 400) ]

lam_kurt_121 = filtered_df_121["lam_kurt"]
mu_kurt_121 = filtered_df_121["mu_kurt"]
RT_121 = filtered_df_121["Response time"]

print(filtered_df_121.head())

filtered_df_4 = df[(df["coeffIAT_sq"] == 4) & (df["lam_kurt"] <= 300) & (df["mu_kurt"] <= 400) ]

lam_kurt_4 = filtered_df_4["lam_kurt"]
mu_kurt_4 = filtered_df_4["mu_kurt"]
RT_4 = filtered_df_4["Response time"]
print(filtered_df_4.head())

filtered_df_25 = df[(df["coeffIAT_sq"] == 25) & (df["lam_kurt"] <= 300) & (df["mu_kurt"] <= 400)]

lam_kurt_25 = filtered_df_25["lam_kurt"]
mu_kurt_25 = filtered_df_25["mu_kurt"]
RT_25 = filtered_df_25["Response time"]
print(filtered_df_25.head())

filtered_df_64 = df[(df["coeffIAT_sq"] == 64) & (df["lam_kurt"] <= 300) & (df["mu_kurt"] <= 400)]

lam_kurt_64 = filtered_df_64["lam_kurt"]
mu_kurt_64 = filtered_df_64["mu_kurt"]
RT_64 = filtered_df_64["Response time"]
print(filtered_df_64.head())
# Out:
#       coeffIAT_sq  coeffST_sq  lam_kurt     mu_kurt  Response time
# 1788         1.21          16  6.112941  307.127520      22.841273
# 965          1.21          16  6.115517  330.607100      22.840990
# 2857         1.21          16  6.117667  293.588591      22.840766
# 2194         1.21          16  6.126448  229.528832      22.840042
# 1196         1.21          16  6.137846  328.680220      22.838766
#       coeffIAT_sq  coeffST_sq   lam_kurt     mu_kurt  Response time
# 4024          4.0          16  12.779336  272.126312      25.161533
# 4189          4.0          16  12.783990  208.902864      25.160923
# 3026          4.0          16  12.786322  252.328830      25.160406
# 5110          4.0          16  12.804318  211.882626      25.157783
# 5927          4.0          16  12.827365  249.752754      25.153852
#       coeffIAT_sq  coeffST_sq   lam_kurt     mu_kurt  Response time
# 6867         25.0          16  75.125870  249.692994      42.665355
# 8435         25.0          16  75.130069  292.594725      42.664514
# 8154         25.0          16  75.390888  339.974591      42.612384
# 7209         25.0          16  75.476410  398.010583      42.595315
# 6801         25.0          16  75.511889  220.060523      42.588745
#        coeffIAT_sq  coeffST_sq    lam_kurt     mu_kurt  Response time
# 9514          64.0          16  192.153037  218.367867      75.144715
# 9108          64.0          16  192.246867  228.991256      75.125487
# 10409         64.0          16  192.506784  196.255521      75.073217
# 11382         64.0          16  192.772129  361.177349      75.017923
# 9464          64.0          16  192.830357  385.258411      75.006007

# %%
fig = plt.figure(figsize=(8, 8))
ax1 = fig.add_subplot( projection='3d')

ax1.scatter3D(lam_kurt_121, mu_kurt_121, RT_121, label = 'CVa = 1.1, CVs = 4')
ax1.scatter3D(lam_kurt_4, mu_kurt_4, RT_4, label = 'CVa = 2, CVs = 4')
ax1.scatter3D(lam_kurt_25, mu_kurt_25, RT_25, label = 'CVa = 5, CVs = 4')
ax1.scatter3D(lam_kurt_64, mu_kurt_64, RT_64, label = 'CVa = 8, CVs = 4')

ax1.set_xlim(0, 300)
ax1.set_ylim(50,400)
ax1.set_zlim(0,100)
ax1.view_init(elev=0, azim=15)


ax1.set_xlabel('Kurtosis of IAT curve')
ax1.set_ylabel('Kurtosis of ST curve')
ax1.set_zlabel('RT for H2/H2/1 as per Tarasov for different Ca, Cs')

for tick in ax1.get_xticklabels():
    tick.set_rotation(60)
    tick.set_horizontalalignment('right')


plt.legend()
plt.show()
