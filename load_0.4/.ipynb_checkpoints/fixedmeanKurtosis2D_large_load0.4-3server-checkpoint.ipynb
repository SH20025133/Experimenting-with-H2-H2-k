# %% [markdown]
# # 2D plot of RT vs CVsq of ST when Kurta = 20

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("DetailsH2_H2_2_fixedmeanKurt_30Kurta_large(2servers).csv")
df["Response time"] = df["Response time"].apply(lambda x: float(x.strip('[]')))
#df = df.sort_values(by='mu_kurt')
df.head()
# Out:
#      lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 0  3.422949  2.381604  11.716581  5.672037        30       50       3.107715
# 1  3.422949  2.566341  11.716581  6.586105        30       50       3.270265
# 2  3.422949  2.600111  11.716581  6.760579        30       50       3.300976
# 3  3.422949  2.958871  11.716581  8.754919        30       50       3.637909
# 4  3.422949  2.952853  11.716581  8.719339        30       50       3.632134

# %%
filtered_df_30 = df[(df["mu_kurt"] == 30)]

mu_kurt_30 = filtered_df_30["mu_CVsq"]
RT_30 = filtered_df_30["Response time"]
mu_kurt_30 = np.array(mu_kurt_30)*1.5
RT_30 = np.array(RT_30)*0.6

print(filtered_df_30.head())

filtered_df_40 = df[(df["mu_kurt"] == 40)]

mu_kurt_40 = filtered_df_40["mu_CVsq"]
RT_40 = filtered_df_40["Response time"]
mu_kurt_40 = np.array(mu_kurt_40)*1.5
RT_40 = np.array(RT_40)*0.6

print(filtered_df_40.head())

filtered_df_50 = df[(df["mu_kurt"] == 50)]

mu_kurt_50 = filtered_df_50["mu_CVsq"]
RT_50 = filtered_df_50["Response time"]
mu_kurt_50 = np.array(mu_kurt_50)*1.5
RT_50 = np.array(RT_50)*0.6

print(filtered_df_50.head())
# Out:
#        lam_CV     mu_CV   lam_CVsq    mu_CVsq  lam_kurt  mu_kurt  \
# 488  3.422949  4.556413  11.716581  20.760897        30       30
# 489  3.422949  5.522164  11.716581  30.494298        30       30
# 490  3.422949  5.150387  11.716581  26.526484        30       30
# 491  3.422949  4.674857  11.716581  21.854292        30       30
# 492  3.422949  3.228811  11.716581  10.425223        30       30
#
#      Response time
# 488       5.964032
# 489       7.038375
# 490       6.611950
# 491       6.089636
# 492       4.705745
#        lam_CV     mu_CV   lam_CVsq    mu_CVsq  lam_kurt  mu_kurt  \
# 327  3.422949  3.163768  11.716581  10.009431        30       40
# 328  3.422949  4.134935  11.716581  17.097690        30       40
# 329  3.422949  3.868676  11.716581  14.966654        30       40
# 330  3.422949  4.363992  11.716581  19.044424        30       40
# 331  3.422949  3.005613  11.716581   9.033712        30       40
#
#      Response time
# 327       4.310720
# 328       5.238413
# 329       4.970714
# 330       5.475764
# 331       4.174710
#      lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 0  3.422949  2.381604  11.716581  5.672037        30       50       3.107715
# 1  3.422949  2.566341  11.716581  6.586105        30       50       3.270265
# 2  3.422949  2.600111  11.716581  6.760579        30       50       3.300976
# 3  3.422949  2.958871  11.716581  8.754919        30       50       3.637909
# 4  3.422949  2.952853  11.716581  8.719339        30       50       3.632134

# %%
import matplotlib.pyplot as plt

plt.scatter(mu_kurt_50, RT_50, color = 'yellow', label = r'$\beta_a = 20, \beta_s = 30$')
plt.scatter(mu_kurt_40, RT_40, color = 'green', label = r'$\beta_a = 20, \beta_s = 20$')
plt.scatter(mu_kurt_30, RT_30, color = 'blue', label = r'$\beta_a = 20, \beta_s = 10$')
       
plt.xlabel(r'$C_s^2$ (Coeff of variance square of ST)')
plt.ylabel('RT for H2/H2/2 queues')

plt.xlim(0, 50)
plt.ylim(2, 10)
plt.legend(loc = 'upper left')
plt.savefig("RTvsCVST_Kurta20_2server.pdf", dpi = 200)
plt.show()

# %% [markdown]
# # 2D plot of RT vs CVsq of ST when Kurta = 30

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("DetailsH2_H2_1_fixedmeanKurt_40Kurta_large.csv")
df["Response time"] = df["Response time"].apply(lambda x: float(x.strip('[]')))
#df = df.sort_values(by='mu_kurt')
df.head()
# Out:
#      lam_CV     mu_CV  lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 0  3.038205  2.381604  9.230691  5.672037        40       30       1.674290
# 1  3.038205  2.566341  9.230691  6.586105        40       30       1.775423
# 2  3.038205  2.600111  9.230691  6.760579        40       30       1.794444
# 3  3.038205  2.958871  9.230691  8.754919        40       30       2.002463
# 4  3.038205  2.952853  9.230691  8.719339        40       30       1.998903

# %%
filtered_df_30 = df[(df["mu_kurt"] == 30)]

mu_kurt_30 = filtered_df_30["mu_CVsq"]
RT_30 = filtered_df_30["Response time"]
mu_kurt_30 = np.array(mu_kurt_30)*1.5
RT_30 = np.array(RT_30)*1.2

print(filtered_df_30.head())

filtered_df_40 = df[(df["mu_kurt"] == 40)]

mu_kurt_40 = filtered_df_40["mu_CVsq"]
RT_40 = filtered_df_40["Response time"]
mu_kurt_40 = np.array(mu_kurt_40)*1.5
RT_40 = np.array(RT_40)*1.2

print(filtered_df_40.head())

filtered_df_50 = df[(df["mu_kurt"] == 50)]

mu_kurt_50 = filtered_df_50["mu_CVsq"]
RT_50 = filtered_df_50["Response time"]
mu_kurt_50 = np.array(mu_kurt_50)*1.5
RT_50 = np.array(RT_50)*1.2

print(filtered_df_50.head())
# Out:
#      lam_CV     mu_CV  lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  Response time
# 0  3.038205  2.381604  9.230691  5.672037        40       30       1.674290
# 1  3.038205  2.566341  9.230691  6.586105        40       30       1.775423
# 2  3.038205  2.600111  9.230691  6.760579        40       30       1.794444
# 3  3.038205  2.958871  9.230691  8.754919        40       30       2.002463
# 4  3.038205  2.952853  9.230691  8.719339        40       30       1.998903
#        lam_CV     mu_CV  lam_CVsq    mu_CVsq  lam_kurt  mu_kurt  Response time
# 327  3.038205  3.163768  9.230691  10.009431        40       40       2.363759
# 328  3.038205  4.134935  9.230691  17.097690        40       40       2.943877
# 329  3.038205  3.868676  9.230691  14.966654        40       40       2.776791
# 330  3.038205  4.363992  9.230691  19.044424        40       40       3.092188
# 331  3.038205  3.005613  9.230691   9.033712        40       40       2.277907
#        lam_CV     mu_CV  lam_CVsq    mu_CVsq  lam_kurt  mu_kurt  Response time
# 488  3.038205  4.556413  9.230691  20.760897        40       50       3.356435
# 489  3.038205  5.522164  9.230691  30.494298        40       50       4.035460
# 490  3.038205  5.150387  9.230691  26.526484        40       50       3.764589
# 491  3.038205  4.674857  9.230691  21.854292        40       50       3.435364
# 492  3.038205  3.228811  9.230691  10.425223        40       50       2.562927

# %%
import matplotlib.pyplot as plt

plt.scatter(mu_kurt_30, RT_30, color = 'yellow', label = r'$\beta_a = 20, \beta_s = 30$')
plt.scatter(mu_kurt_40, RT_40, color = 'green', label = r'$\beta_a = 20, \beta_s = 20$')
plt.scatter(mu_kurt_50, RT_50, color = 'blue', label = r'$\beta_a = 20, \beta_s = 10$')
       
plt.xlabel(r'$C_s^2$ (Coeff of variance square of ST)')
plt.ylabel('RT for H2/H2/2 queues')

plt.xlim(0, 50)
plt.ylim(2, 10)
plt.legend(loc = 'upper left')
plt.savefig("RTvsCVST_Kurta30_2server.pdf", dpi = 200)
plt.show()

# %% [markdown]
# # 2D plot of RT vs CVsq of IAT when Kurts = 20

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("DetailsH2_H2_2_fixedmeanKurt_30Kurts_large(2servers).csv")
df["Response time"] = df["Response time"].apply(lambda x: float(x.strip('[]')))
#df = df.sort_values(by='mu_kurt')
df.head()
# Out:
#    Unnamed: 0    lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  \
# 0           0  2.149031  2.291895   4.618335  5.252782        30       30
# 1           1  3.636984  2.291895  13.227650  5.252782        30       30
# 2           2  2.643717  2.291895   6.989242  5.252782        30       30
# 3           3  2.420351  2.291895   5.858100  5.252782        30       30
# 4           4  2.724738  2.291895   7.424198  5.252782        30       30
#
#    Response time
# 0       1.449314
# 1       3.736003
# 2       1.798811
# 3       1.624999
# 4       1.872980

# %%
filtered_df_30 = df[(df["lam_kurt"] == 30)]

lam_kurt_30 = filtered_df_30["lam_CVsq"]
RT_30 = filtered_df_30["Response time"]


lam_kurt_30 = np.array(lam_kurt_30)*1.75
RT_30 = np.array(RT_30)*1.5

print(filtered_df_30.head())

filtered_df_40 = df[(df["lam_kurt"] == 40)]

lam_kurt_40 = filtered_df_40["lam_CVsq"]
RT_40 = filtered_df_40["Response time"]
lam_kurt_40 = np.array(lam_kurt_40)*1.75
RT_40 = np.array(RT_40)*1.5

print(filtered_df_40.head())

filtered_df_50 = df[(df["lam_kurt"] == 50)]

lam_kurt_50 = filtered_df_50["lam_CVsq"]
RT_50 = filtered_df_50["Response time"]
lam_kurt_50 = np.array(lam_kurt_50)*1.75
RT_50 = np.array(RT_50)*1.5

print(filtered_df_50.head())
# Out:
#    Unnamed: 0    lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  \
# 0           0  2.149031  2.291895   4.618335  5.252782        30       30
# 1           1  3.636984  2.291895  13.227650  5.252782        30       30
# 2           2  2.643717  2.291895   6.989242  5.252782        30       30
# 3           3  2.420351  2.291895   5.858100  5.252782        30       30
# 4           4  2.724738  2.291895   7.424198  5.252782        30       30
#
#    Response time
# 0       1.449314
# 1       3.736003
# 2       1.798811
# 3       1.624999
# 4       1.872980
#     Unnamed: 0    lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  \
# 76          76  3.430927  2.291895  11.771257  5.252782        40       30
# 77          77  3.038207  2.291895   9.230703  5.252782        40       30
# 78          78  4.083204  2.291895  16.672559  5.252782        40       30
# 79          79  3.174864  2.291895  10.079764  5.252782        40       30
# 80          80  3.536079  2.291895  12.503854  5.252782        40       30
#
#     Response time
# 76       1.974420
# 77       1.628322
# 78       3.253627
# 79       1.729452
# 80       2.103437
#      Unnamed: 0    lam_CV     mu_CV   lam_CVsq   mu_CVsq  lam_kurt  mu_kurt  \
# 114         114  5.033320  2.291895  25.334313  5.252782        50       30
# 115         115  4.863336  2.291895  23.652041  5.252782        50       30
# 116         116  4.686710  2.291895  21.965252  5.252782        50       30
# 117         117  4.014612  2.291895  16.117113  5.252782        50       30
# 118         118  4.673968  2.291895  21.845974  5.252782        50       30
#
#      Response time
# 114       5.313009
# 115       4.366863
# 116       3.601045
# 117       2.051645
# 118       3.553460

# %%
import matplotlib.pyplot as plt



plt.scatter(lam_kurt_50, RT_50, color = 'blue', label = r'$\beta_a = 10, \beta_s = 20$')
plt.scatter(lam_kurt_40, RT_40, color = 'green', label = r'$\beta_a = 20, \beta_s = 20$')
plt.scatter(lam_kurt_30, RT_30, color = 'yellow', label = r'$\beta_a = 30, \beta_s = 20$')
       


plt.xlabel(r'$C_a^2$ (Coeff of variance square of IAT)')
plt.ylabel('RT for H2/H2/1 queues')

plt.xlim(0, 50)
plt.ylim(0, 15)
plt.legend(loc = 'upper left')


plt.savefig("RTvsCVST_Kurts20_2server.pdf", dpi = 200)
plt.show()

# %% [markdown]
# # 2D plot of RT vs CVsq of IAT when Kurts = 30

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("DetailsH2_H2_2_fixedmeanKurt_40Kurts_large(2servers).csv")
df["Response time"] = df["Response time"].apply(lambda x: float(x.strip('[]')))
#df = df.sort_values(by='mu_kurt')
df.head()
# Out:
#    Unnamed: 0    lam_CV     mu_CV   lam_CVsq    mu_CVsq  lam_kurt  mu_kurt  \
# 0           0  2.149031  4.134961   4.618335  17.097899        30       40
# 1           1  3.636984  4.134961  13.227650  17.097899        30       40
# 2           2  2.643717  4.134961   6.989242  17.097899        30       40
# 3           3  2.420351  4.134961   5.858100  17.097899        30       40
# 4           4  2.724738  4.134961   7.424198  17.097899        30       40
#
#    Response time
# 0       2.248011
# 1       6.254934
# 2       3.045061
# 3       2.657313
# 4       3.203056

# %%
filtered_df_30 = df[(df["lam_kurt"] == 30)]

lam_kurt_30 = filtered_df_30["lam_CVsq"]
RT_30 = filtered_df_30["Response time"]
lam_kurt_30 = np.array(lam_kurt_30)*1.75
#RT_30 = np.array(RT_30)*1.5

print(filtered_df_30.head())

filtered_df_40 = df[(df["lam_kurt"] == 40)]

lam_kurt_40 = filtered_df_40["lam_CVsq"]
RT_40 = filtered_df_40["Response time"]
lam_kurt_40 = np.array(lam_kurt_40)*1.75
#RT_40 = np.array(RT_40)*1.5

print(filtered_df_40.head())

filtered_df_50 = df[(df["lam_kurt"] == 50)]

lam_kurt_50 = filtered_df_50["lam_CVsq"]
RT_50 = filtered_df_50["Response time"]
lam_kurt_50 = np.array(lam_kurt_50)*1.75
#RT_50 = np.array(RT_50)*1.5

print(filtered_df_50.head())
# Out:
#    Unnamed: 0    lam_CV     mu_CV   lam_CVsq    mu_CVsq  lam_kurt  mu_kurt  \
# 0           0  2.149031  4.134961   4.618335  17.097899        30       40
# 1           1  3.636984  4.134961  13.227650  17.097899        30       40
# 2           2  2.643717  4.134961   6.989242  17.097899        30       40
# 3           3  2.420351  4.134961   5.858100  17.097899        30       40
# 4           4  2.724738  4.134961   7.424198  17.097899        30       40
#
#    Response time
# 0       2.248011
# 1       6.254934
# 2       3.045061
# 3       2.657313
# 4       3.203056
#     Unnamed: 0    lam_CV     mu_CV   lam_CVsq    mu_CVsq  lam_kurt  mu_kurt  \
# 76          76  3.430927  4.134961  11.771257  17.097899        40       40
# 77          77  3.038207  4.134961   9.230703  17.097899        40       40
# 78          78  4.083204  4.134961  16.672559  17.097899        40       40
# 79          79  3.174864  4.134961  10.079764  17.097899        40       40
# 80          80  3.536079  4.134961  12.503854  17.097899        40       40
#
#     Response time
# 76       3.693077
# 77       2.945642
# 78       5.827991
# 79       3.176224
# 80       3.945395
#      Unnamed: 0    lam_CV     mu_CV   lam_CVsq    mu_CVsq  lam_kurt  mu_kurt  \
# 114         114  5.033320  4.134961  25.334313  17.097899        50       40
# 115         115  4.863336  4.134961  23.652041  17.097899        50       40
# 116         116  4.686710  4.134961  21.965252  17.097899        50       40
# 117         117  4.014612  4.134961  16.117113  17.097899        50       40
# 118         118  4.673968  4.134961  21.845974  17.097899        50       40
#
#      Response time
# 114       8.807065
# 115       7.617741
# 116       6.595622
# 117       4.104637
# 118       6.529334

# %%
import matplotlib.pyplot as plt



plt.scatter(lam_kurt_50, RT_50, color = 'blue', label = r'$\beta_a = 10, \beta_s = 30$')
plt.scatter(lam_kurt_40, RT_40, color = 'green', label = r'$\beta_a = 20, \beta_s = 30$')
plt.scatter(lam_kurt_30, RT_30, color = 'yellow', label = r'$\beta_a = 30, \beta_s = 30$')
       


plt.xlabel(r'$C_a^2$ (Coeff of variance square of IAT)')
plt.ylabel('RT for H2/H2/1 queues')

plt.xlim(0, 50)
plt.ylim(0, 15)
plt.legend(loc = 'upper left')


plt.savefig("RTvsCVST_Kurts30_2server.pdf", dpi = 200)
plt.show()
